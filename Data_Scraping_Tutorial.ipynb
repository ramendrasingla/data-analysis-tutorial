# %% [markdown]
# <a href="https://colab.research.google.com/github/ramendrasingla/data_analysis_tutorial/blob/main/Data_Scraping_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
from IPython.display import Image

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Part - 1

# %% [markdown]
# ## Data Scraping
# * The act of importing data from a website into a spreadsheet or locally stored file on your computer is known as data scraping, often referred to as web scraping. It's one of the best methods for obtaining information on the internet and, in some cases, for sending that information to another website.
# * Typical applications for data scraping include:
# *  Web content/business intelligence research
#
# > 1.  Pricing for price comparison and trip booking websites
# 2.  Utilizing public data sources to find sales leads and carry out market research (e.g. Yell and Twitter)
# 3. Sending product information from one online retailer to another (e.g. Google Shopping)
# 4. And many more...
#
# * Most of this data will be in unstructured or HTML format, which can be further parsed and converted into a structured format for further analysis. In theory, you can scrape any data on the Internet. The most common data types scraped include text, images, videos, pricing, reviews, product information, etc.
# * You can use **online Web Scraping services** or **APIs** or create your **own custom-built code** to scrape the information

# %%
Image(filename='/content/drive/MyDrive/Newton School/Data Scraping/data_scraping_uses.jpeg', width = 700)

# %% [markdown]
# ## Working of Data Scrapers?
# 1. HTTP Requests
# 2. Loading/Parsing Website Code
# 3. Extracting essential information

# %% [markdown]
# ## Can we scrape every website?
# We can confirm that using *robots.txt*
#
# * [Google.com](https://google.com/robots.txt)
# * [Amazon.com](https://www.amazon.com/robots.txt)

# %% [markdown]
# ## Example Usecase:
#
# **I am interested on online face mask price, discount, ratings, sold quantity etc.**

# %%
Image(filename='/content/drive/MyDrive/Newton School/Data Scraping/data-scraping-example-problem.png')

# %%
Image(filename='/content/drive/MyDrive/Newton School/Data Scraping/data-scraping-example-solution.png')

# %% [markdown]
# ## Requests:

# %%
Image(filename='/content/drive/MyDrive/Newton School/Data Scraping/http-request.png')

# %% [markdown]
# * Entering the website URL, the browser doesn't know which computer out there has information for that site, so it essentially looks a phone book that has all the list of websites in the world and the “IP address” that corresponds to each website. This phone book is basically called a **DNS server**
# * After looking at the DNS server and finding which computer to talk to, the HTTP request is sent to the appropriate server. The server processes that request and sends information back to the browser. The browser then renders that information on its screen.

# %%
Image(filename='/content/drive/MyDrive/Newton School/Data Scraping/http-request-2.png')

# %% [markdown]
# * [Credit - Medium Article on HTTP Request](https://medium.com/p/76780d4cb14c)
